# %%
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DataConversionWarning)
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier, AdaBoostRegressor
from sklearn.linear_model import SGDRegressor, LinearRegression, SGDClassifier
from xgboost.sklearn import XGBClassifier, XGBRegressor, XGBRFRegressor, XGBRFClassifier
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv('ver1.csv', index_col=['id'])
# display(df.columns)
df.drop(columns=['production_countries', 'production_companies', 'genres', 'release_date', 
                 'popularity_norm', 'year', 'original_language', 'fr', 'ru', 'es', 'hi', 
                 'ja', 'it', 'ko', 'cn', 'zh', 'others', 'month', 'date'], inplace=True)

df.drop(columns=['production_countries', 'production_companies', 'genres', 'release_date', 
                 'popularity_norm', 'others'], inplace=True)

df_norm = df

# df_norm_mean = df_norm.mean()
# df_norm_std = df_norm.std()

# df_norm = (df_norm - df_norm_mean) / df_norm_std
# df_norm['en'] = df['en']
display(df_norm)


X = df_norm.drop(columns=['revenue'])
y = df_norm[['revenue']]
y_bin, bins = pd.qcut(y['revenue'], 10,retbins=True, labels=[*range(10)])

X_train, X_test = train_test_split(df_norm, test_size = 0.1, random_state=123)

X_train = pd.DataFrame(data=X_train)
y_train = X_train[['revenue']]
X_train = X_train.drop(columns=['revenue'])
X_test = pd.DataFrame(data=X_test)
y_test = X_test[['revenue']]
X_test = X_test.drop(columns=['revenue'])
y_train_bin = pd.cut(y_train['revenue'], bins=bins, labels=[*range(10)], include_lowest=True)
y_test_bin = pd.cut(y_test['revenue'], bins=bins, labels=[*range(10)], include_lowest=True)
# Out:
#           budget  popularity   revenue   runtime  vote_average  vote_count  \
# id
# 5      -0.837473   -0.182568 -0.635929 -0.615447      0.213421   -0.326808
# 11     -0.680285    2.666589  3.479701  0.481086      2.058488    3.959233
# 12      1.183519    1.546249  4.360033 -0.520096      1.481905    3.606166
# 13      0.307756    2.989704  2.959561  1.482269      2.173805    4.875661
# 14     -0.590463    1.413857  1.242805  0.528762      1.827855    1.630536
# ...          ...         ...       ...       ...           ...         ...
# 365222 -0.118898   -0.284649  0.178258 -0.281719      0.213421   -0.433010
# 375290 -0.826245   -0.741973 -0.488084  0.719463      1.135955   -0.659479
# 376659 -0.478185    0.357884  0.322854 -0.520096     -0.017212    0.180990
# 381902  0.610680   -0.682117  0.374845  0.433411     -0.363162   -0.682689
# 417859  1.991916   -0.243050  2.303290 -0.996850      0.098105   -0.382371
#
#          quarter        en
# id
# 5       1.253251  0.199213
# 11     -0.581184  0.199213
# 12     -0.581184  0.199213
# 13      0.336033  0.199213
# 14      0.336033  0.199213
# ...          ...       ...
# 365222  1.253251 -5.018180
# 375290 -1.498402 -5.018180
# 376659  0.336033  0.199213
# 381902 -1.498402 -5.018180
# 417859  1.253251  0.199213
#
# [3169 rows x 8 columns]

# %%
ada_reg_dt = AdaBoostRegressor()

# %%
ada_reg_dt_dict = cross_validate(ada_reg_dt ,X, y, cv=20, return_train_score=True, return_estimator=True)

# %%
display(ada_reg_dt_dict['train_score'])
display(ada_reg_dt_dict['test_score'])
# Out:
# array([0.49349011, 0.64504082, 0.65976968, 0.50277858, 0.59844869,
#        0.71277747, 0.52553717, 0.5536304 , 0.58987802, 0.57261573,
#        0.59073685, 0.62913917, 0.50955714, 0.52485467, 0.42517581,
#        0.60092005, 0.40026897, 0.35996618, 0.54848233, 0.67933896])
# array([ 0.46415572,  0.61784021,  0.50889879,  0.4745423 , -0.08972157,
#         0.35224288,  0.25652394,  0.1017664 ,  0.46960361,  0.20225739,
#         0.0057209 ,  0.39065708,  0.49392566,  0.41827999,  0.3330635 ,
#         0.56074793,  0.10365882,  0.5869135 ,  0.32040886,  0.4708383 ])

# %%
ada_reg_sgd = AdaBoostRegressor(base_estimator=SGDRegressor(learning_rate='adaptive', max_iter=3000))

# %%
ada_reg_sgd_dict = cross_validate(ada_reg_sgd ,X, y, cv=20, return_train_score=True, return_estimator=True)

# %%
display(ada_reg_sgd_dict['train_score'])
display(ada_reg_sgd_dict['test_score'])
# Out:
# array([0.62138905, 0.48653533, 0.64970488, 0.63136949, 0.64727554,
#        0.64995865, 0.63821331, 0.47658429, 0.60838541, 0.60588151,
#        0.508353  , 0.64872053, 0.68186022, 0.48712626, 0.63345322,
#        0.62855096, 0.63612808, 0.6157856 , 0.63645694, 0.62458906])
# array([0.60246586, 0.5128661 , 0.57310685, 0.57803875, 0.39129852,
#        0.42894712, 0.5388566 , 0.19157791, 0.52597198, 0.41225302,
#        0.32739512, 0.61458462, 0.68690414, 0.48351411, 0.69346867,
#        0.62738759, 0.09288119, 0.79116494, 0.43274865, 0.63401315])

# %%
ada_reg_lr = AdaBoostRegressor(base_estimator=LinearRegression())

# %%
ada_reg_lr_dict = cross_validate(ada_reg_lr ,X, y, cv=20, return_train_score=True, return_estimator=True)

# %%
display(ada_reg_lr_dict['train_score'])
display(ada_reg_lr_dict['test_score'])
# Out:
# array([0.61287314, 0.63245799, 0.61872298, 0.65011541, 0.61828361,
#        0.63226412, 0.61937434, 0.65021975, 0.62749667, 0.64623453,
#        0.62588115, 0.62595281, 0.66677454, 0.63031219, 0.60823386,
#        0.63624753, 0.65780619, 0.6111988 , 0.63441935, 0.6002106 ])
# array([0.62019604, 0.55985146, 0.56279133, 0.64312539, 0.27701135,
#        0.39958293, 0.52545261, 0.50194942, 0.59130716, 0.46815731,
#        0.46949843, 0.56175357, 0.66849427, 0.56354992, 0.63700142,
#        0.63795891, 0.20754237, 0.79029824, 0.45720317, 0.59863458])

# %%
ada_clf_dt = AdaBoostClassifier()

# %%
ada_clf_dt_dict = cross_validate(ada_clf_dt ,X, y_bin, cv=20, return_train_score=True, return_estimator=True)

# %%
display(ada_clf_dt_dict['train_score'])
display(ada_clf_dt_dict['test_score'])
# Out:
# array([0.28580924, 0.28946494, 0.28880027, 0.28348288, 0.27650382,
#        0.26952476, 0.28015952, 0.28846793, 0.28148887, 0.28414756,
#        0.28015952, 0.29411765, 0.27949485, 0.29345297, 0.29378531,
#        0.29378531, 0.28737542, 0.28618748, 0.28817489, 0.28817489])
# array([0.24375   , 0.25625   , 0.24375   , 0.26875   , 0.26875   ,
#        0.225     , 0.3       , 0.325     , 0.20625   , 0.33125   ,
#        0.25      , 0.25      , 0.30625   , 0.30625   , 0.3       ,
#        0.2875    , 0.27044025, 0.22      , 0.25333333, 0.19333333])

# %%
y_train_bin, X_train
# Out:
# (id
#  9779      4
#  598       3
#  1588      6
#  1125      7
#  4547      8
#           ..
#  27029     1
#  290595    7
#  13183     8
#  9428      5
#  10160     2
#  Name: revenue, Length: 2852, dtype: category
#  Categories (10, int64): [0 < 1 < 2 < 3 ... 6 < 7 < 8 < 9],
#            budget  popularity   runtime  vote_average  vote_count   quarter  \
#  id
#  9779   -0.365908   -0.339521  0.385736     -0.017212   -0.428086 -0.581184
#  598    -0.853192    0.408648  0.910165      2.058488    0.576257 -1.498402
#  1588   -0.298542   -0.406112 -0.615447     -0.593795   -0.300082  0.336033
#  1125    0.644588   -0.413488  1.100866      0.328738   -0.499825  1.253251
#  4547    0.150568    0.647728  0.004333      0.213421    0.191540 -1.498402
#  ...          ...         ...       ...           ...         ...       ...
#  27029  -0.848701   -0.721883  1.815996      1.251272   -0.667216 -0.581184
#  290595  1.655084    0.852086  0.147359     -0.363162    0.371590 -0.581184
#  13183   1.991916    0.971287  2.483451      0.790005    1.277468 -1.498402
#  9428   -0.455730   -0.148038 -0.043343      1.251272    0.204903  1.253251
#  10160  -0.747651   -0.463918 -1.044525     -0.939746   -0.527255  0.336033
#
#                en
#  id
#  9779    0.199213
#  598    -5.018180
#  1588    0.199213
#  1125    0.199213
#  4547    0.199213
#  ...          ...
#  27029   0.199213
#  290595  0.199213
#  13183   0.199213
#  9428    0.199213
#  10160   0.199213
#
#  [2852 rows x 7 columns])

# %%
xgb_clf = XGBClassifier(verbosity=1, n_jobs=14, gpu_id=0, eval_metrics='merror')

# %%
xgb_clf_gscv = GridSearchCV(xgb_clf, param_grid={
    'max_dept': [3, 8],
    'booster': ['gbtree'],
    'objective': ['multi:softmax', 'multi:softprob'],
    'n_estimators': [600]
}, return_train_score=True, cv=20, verbose=3)
xgb_clf_gscv.fit(X, y_bin)
# Out:
# Fitting 20 folds for each of 4 candidates, totalling 80 fits
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.857, test=0.237), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.856, test=0.219), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.8s remaining:    0.0s
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.851, test=0.237), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.858, test=0.269), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.847, test=0.287), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.850, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.848, test=0.269), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.855, test=0.331), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.846, test=0.275), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.854, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.851, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.857, test=0.300), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.859, test=0.275), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.846, test=0.306), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.857, test=0.344), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.854, test=0.312), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.849, test=0.296), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.854, test=0.240), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.847, test=0.247), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.852, test=0.207), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.857, test=0.237), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.856, test=0.219), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.851, test=0.237), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.858, test=0.269), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.847, test=0.287), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.850, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.848, test=0.269), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.855, test=0.331), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.846, test=0.275), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.854, test=0.294), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.851, test=0.294), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.857, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.859, test=0.275), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.846, test=0.306), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.857, test=0.344), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.854, test=0.312), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.849, test=0.296), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.854, test=0.240), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.847, test=0.247), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.852, test=0.207), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.857, test=0.237), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.856, test=0.219), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.851, test=0.237), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.858, test=0.269), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.847, test=0.287), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.850, test=0.300), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.848, test=0.269), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.855, test=0.331), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.846, test=0.275), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.854, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.851, test=0.294), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.857, test=0.300), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.859, test=0.275), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.846, test=0.306), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.857, test=0.344), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.854, test=0.312), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.849, test=0.296), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.854, test=0.240), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.847, test=0.247), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.852, test=0.207), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-4910b9f85cf4> in <module>
#       5     'n_estimators': [600]
#       6 }, return_train_score=True, cv=20, verbose=3)
# ----> 7 xgb_clf_gscv.fit(X, y_bin)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1147     def _run_search(self, evaluate_candidates):
#    1148         """Search all candidates in param_grid"""
# -> 1149         evaluate_candidates(ParameterGrid(self.param_grid))
#    1150
#    1151
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1004                 self._iterating = self._original_iterator is not None
#    1005
# -> 1006             while self.dispatch_one_batch(iterator):
#    1007                 pass
#    1008
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     832                 return False
#     833             else:
# --> 834                 self._dispatch(tasks)
#     835                 return True
#     836
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     751         with self._lock:
#     752             job_idx = len(self._jobs)
# --> 753             job = self._backend.apply_async(batch, callback=cb)
#     754             # A job can complete so quickly than its callback is
#     755             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     199     def apply_async(self, func, callback=None):
#     200         """Schedule a func to be run"""
# --> 201         result = ImmediateResult(func)
#     202         if callback:
#     203             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     580         # Don't delay the application, to avoid keeping the input
#     581         # arguments in memory
# --> 582         self.results = batch()
#     583
#     584     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
pd.DataFrame(xgb_clf_gscv.cv_results_)#[['mean_test_score']]

# %%
xgb_rf_clf = XGBRFClassifier(verbosity=1, n_jobs=14, gpu_id=0, eval_metrics='merror')

# %%
xgb_rf_clf_gscv = GridSearchCV(xgb_rf_clf, param_grid={
    'max_dept': [3, 8],
    'booster': ['gbtree'],
    'objective': ['multi:softmax', 'multi:softprob'],
    'n_estimators': [600]
}, return_train_score=True, cv=20, verbose=3)
xgb_rf_clf_gscv.fit(X, y_bin)
# Out:
# Fitting 20 folds for each of 4 candidates, totalling 80 fits
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.345, test=0.237), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.200), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.9s remaining:    0.0s
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.337, test=0.256), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.344, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.338, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.349, test=0.306), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.351, test=0.338), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.343, test=0.338), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.338, test=0.225), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.341, test=0.356), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.349, test=0.356), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.351, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.346, test=0.312), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.287), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.344, test=0.225), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.289), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.353, test=0.273), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.350, test=0.233), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softmax, score=(train=0.347, test=0.227), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.345, test=0.237), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.200), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.337, test=0.256), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.344, test=0.294), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.338, test=0.300), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.349, test=0.306), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.351, test=0.338), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.343, test=0.338), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.338, test=0.225), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.341, test=0.356), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.349, test=0.356), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.351, test=0.300), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.346, test=0.312), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.287), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.294), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.344, test=0.225), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.289), total=   1.8s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.353, test=0.273), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.350, test=0.233), total=   1.9s
# [CV] booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=3, n_estimators=600, objective=multi:softprob, score=(train=0.347, test=0.227), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.345, test=0.237), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.200), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.337, test=0.256), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.344, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.338, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.349, test=0.306), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.351, test=0.338), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.343, test=0.338), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.338, test=0.225), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.341, test=0.356), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.349, test=0.356), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.351, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.346, test=0.312), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.287), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.344, test=0.225), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.342, test=0.289), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.353, test=0.273), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.350, test=0.233), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softmax, score=(train=0.347, test=0.227), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.345, test=0.237), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.200), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.337, test=0.256), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.344, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.338, test=0.300), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.349, test=0.306), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.351, test=0.338), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.343, test=0.338), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.338, test=0.225), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.341, test=0.356), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.349, test=0.356), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.351, test=0.300), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.346, test=0.312), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.287), total=   1.8s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.294), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.344, test=0.225), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.342, test=0.289), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.353, test=0.273), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.350, test=0.233), total=   1.9s
# [CV] booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob
# [CV]  booster=gbtree, max_dept=8, n_estimators=600, objective=multi:softprob, score=(train=0.347, test=0.227), total=   1.9s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  2.5min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=20, error_score='raise-deprecating',
#              estimator=XGBRFClassifier(base_score=0.5, colsample_bylevel=1,
#                                        colsample_bynode=0.8, colsample_bytree=1,
#                                        eval_metrics='merror', gamma=0, gpu_id=0,
#                                        learning_rate=1, max_delta_step=0,
#                                        max_depth=3, min_child_weight=1,
#                                        missing=None, n_estimators=100,
#                                        n_jobs=14, nthread=None,
#                                        objective='binary:logistic',
#                                        random_state=0, reg_alpha=0,
#                                        reg_lambda=1, scale_pos_weight=1,
#                                        seed=None, silent=None, subsample=0.8,
#                                        verbosity=1),
#              iid='warn', n_jobs=None,
#              param_grid={'booster': ['gbtree'], 'max_dept': [3, 8],
#                          'n_estimators': [600],
#                          'objective': ['multi:softmax', 'multi:softprob']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=3)

# %%
pd.DataFrame(xgb_rf_clf_gscv.cv_results_)[['mean_test_score']]
# Out:
#    mean_test_score
# 0         0.282739
# 1         0.282739
# 2         0.282739
# 3         0.282739

# %%
xgb_reg = XGBRegressor(eval_metrics='rmse', verbosity=1, n_jobs=14, gpu_id=0)

# %%
xgb_reg_gscv = GridSearchCV(xgb_reg, param_grid={
#     'max_dept': [*range(3, 9)],
    'feature_selector': ['cyclic', 'greedy', 'thrifty'],
    'max_depth': [*range(3, 9, 2)],
    'top_k': [*range(1, 5)]
    'objective': ['reg:squarederror']
    
}, return_train_score=True, cv=20, verbose=3)
xgb_reg_gscv.fit(X, y)

# %%
pd.DataFrame(xgb_reg_gscv.cv_results_)[['mean_test_score']]

# %%
xgb_rf_reg = XGBRFRegressor(eval_metrics='rmse', verbosity=1, n_jobs=14, gpu_id=0)

# %%
xgb_rf_reg_gscv = GridSearchCV(xgb_rf_reg, param_grid={
    'feature_selector': ['cyclic', 'greedy', 'thrifty'],
    'max_depth': [*range(3, 9, 2)],
    'top_k': [*range(1, 5)],
    'objective': ['reg:squarederror']
    
}, return_train_score=True, cv=20, verbose=3)
xgb_rf_reg_gscv.fit(X, y)
# Out:
# Fitting 20 folds for each of 36 candidates, totalling 720 fits
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.715, test=0.615), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.716, test=0.600), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.721, test=0.576), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.713, test=0.708), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.713, test=0.431), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.714, test=0.553), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.716, test=0.525), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.713, test=0.664), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.710, test=0.721), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.711, test=0.665), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.712, test=0.613), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.708, test=0.801), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.715, test=0.505), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.705, test=0.706), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.708, test=0.724), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.711, test=0.764), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.720, test=0.495), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.696, test=0.775), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.715, test=0.595), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=1, score=(train=0.712, test=0.656), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.715, test=0.615), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.716, test=0.600), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.721, test=0.576), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.713, test=0.708), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.713, test=0.431), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.714, test=0.553), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.716, test=0.525), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.713, test=0.664), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.710, test=0.721), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.711, test=0.665), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.712, test=0.613), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.708, test=0.801), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.715, test=0.505), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.705, test=0.706), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.708, test=0.724), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.711, test=0.764), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.720, test=0.495), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.696, test=0.775), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.715, test=0.595), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=2, score=(train=0.712, test=0.656), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.715, test=0.615), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.716, test=0.600), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.721, test=0.576), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.713, test=0.708), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.713, test=0.431), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.714, test=0.553), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.716, test=0.525), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.713, test=0.664), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.710, test=0.721), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.711, test=0.665), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.712, test=0.613), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.708, test=0.801), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.715, test=0.505), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.705, test=0.706), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.708, test=0.724), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.711, test=0.764), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.720, test=0.495), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.696, test=0.775), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.715, test=0.595), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=3, score=(train=0.712, test=0.656), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.715, test=0.615), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.716, test=0.600), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.721, test=0.576), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.713, test=0.708), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.713, test=0.431), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.714, test=0.553), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.716, test=0.525), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.713, test=0.664), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.710, test=0.721), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.711, test=0.665), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.712, test=0.613), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.708, test=0.801), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.715, test=0.505), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.705, test=0.706), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.708, test=0.724), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.711, test=0.764), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.720, test=0.495), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.696, test=0.775), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.715, test=0.595), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=3, objective=reg:squarederror, top_k=4, score=(train=0.712, test=0.656), total=   0.0s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.789, test=0.643), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.787, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.792, test=0.617), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.789, test=0.515), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.788, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.787, test=0.595), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.787, test=0.658), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.784, test=0.757), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.784, test=0.745), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.785, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.781, test=0.804), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.786, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.779, test=0.811), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.784, test=0.765), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.784, test=0.789), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.791, test=0.604), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.776, test=0.784), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.786, test=0.623), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=1, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.789, test=0.643), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.787, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.792, test=0.617), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.789, test=0.515), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.788, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.787, test=0.595), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.787, test=0.658), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.784, test=0.757), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.784, test=0.745), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.785, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.781, test=0.804), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.786, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.779, test=0.811), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.784, test=0.765), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.784, test=0.789), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.791, test=0.604), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.776, test=0.784), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.786, test=0.623), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=2, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.789, test=0.643), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.787, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.792, test=0.617), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.789, test=0.515), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.788, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.787, test=0.595), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.787, test=0.658), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.784, test=0.757), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.784, test=0.745), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.785, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.781, test=0.804), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.786, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.779, test=0.811), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.784, test=0.765), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.784, test=0.789), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.791, test=0.604), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.776, test=0.784), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.786, test=0.623), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=3, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.789, test=0.643), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.787, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.792, test=0.617), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.789, test=0.515), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.788, test=0.615), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.787, test=0.595), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.787, test=0.658), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.784, test=0.757), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.784, test=0.745), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.785, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.781, test=0.804), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.786, test=0.605), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.779, test=0.811), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.784, test=0.765), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.784, test=0.789), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.791, test=0.604), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.776, test=0.784), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.786, test=0.623), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=5, objective=reg:squarederror, top_k=4, score=(train=0.786, test=0.707), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.837, test=0.610), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.834, test=0.612), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.840, test=0.648), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.832, test=0.697), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.837, test=0.520), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.836, test=0.609), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.835, test=0.606), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.835, test=0.652), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.833, test=0.776), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.831, test=0.780), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.834, test=0.586), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.830, test=0.805), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.835, test=0.616), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.827, test=0.834), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.832, test=0.780), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.831, test=0.798), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.836, test=0.639), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.826, test=0.782), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.832, test=0.632), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.834, test=0.694), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.837, test=0.610), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.834, test=0.612), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.840, test=0.648), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.832, test=0.697), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.837, test=0.520), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.836, test=0.609), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.835, test=0.606), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.835, test=0.652), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.833, test=0.776), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.831, test=0.780), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.834, test=0.586), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.830, test=0.805), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.835, test=0.616), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.827, test=0.834), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.832, test=0.780), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.831, test=0.798), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.836, test=0.639), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.826, test=0.782), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.832, test=0.632), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.834, test=0.694), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.837, test=0.610), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.834, test=0.612), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.840, test=0.648), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.832, test=0.697), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.837, test=0.520), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.836, test=0.609), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.835, test=0.606), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.835, test=0.652), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.833, test=0.776), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.831, test=0.780), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.834, test=0.586), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.830, test=0.805), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.835, test=0.616), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.827, test=0.834), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.832, test=0.780), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.831, test=0.798), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.836, test=0.639), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.826, test=0.782), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.832, test=0.632), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.834, test=0.694), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.837, test=0.610), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.834, test=0.612), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.840, test=0.648), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.832, test=0.697), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.837, test=0.520), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.836, test=0.609), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.835, test=0.606), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.835, test=0.652), total=   0.1s
# [CV] feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=cyclic, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.833, test=0.776), total=   0.1s
# ...
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.834, test=0.586), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.830, test=0.805), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.835, test=0.616), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.827, test=0.834), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.832, test=0.780), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.831, test=0.798), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.836, test=0.639), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.826, test=0.782), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.832, test=0.632), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=1, score=(train=0.834, test=0.694), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.837, test=0.610), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.834, test=0.612), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.840, test=0.648), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.832, test=0.697), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.837, test=0.520), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.836, test=0.609), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.835, test=0.606), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.835, test=0.652), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.833, test=0.776), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.831, test=0.780), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.834, test=0.586), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.830, test=0.805), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.835, test=0.616), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.827, test=0.834), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.832, test=0.780), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.831, test=0.798), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.836, test=0.639), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.826, test=0.782), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.832, test=0.632), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=2, score=(train=0.834, test=0.694), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.837, test=0.610), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.834, test=0.612), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.840, test=0.648), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.832, test=0.697), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.837, test=0.520), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.836, test=0.609), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.835, test=0.606), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.835, test=0.652), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.833, test=0.776), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.831, test=0.780), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.834, test=0.586), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.830, test=0.805), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.835, test=0.616), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.827, test=0.834), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.832, test=0.780), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.831, test=0.798), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.836, test=0.639), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.826, test=0.782), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.832, test=0.632), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=3, score=(train=0.834, test=0.694), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.837, test=0.610), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.834, test=0.612), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.840, test=0.648), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.832, test=0.697), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.837, test=0.520), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.836, test=0.609), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.835, test=0.606), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.835, test=0.652), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.833, test=0.776), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.831, test=0.780), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.834, test=0.586), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.830, test=0.805), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.835, test=0.616), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.827, test=0.834), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.832, test=0.780), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.831, test=0.798), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.836, test=0.639), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.826, test=0.782), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.832, test=0.632), total=   0.1s
# [CV] feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4
# [CV]  feature_selector=thrifty, max_depth=7, objective=reg:squarederror, top_k=4, score=(train=0.834, test=0.694), total=   0.1s
# [Parallel(n_jobs=1)]: Done 720 out of 720 | elapsed:   44.8s finished
# GridSearchCV(cv=20, error_score='raise-deprecating',
#              estimator=XGBRFRegressor(base_score=0.5, colsample_bylevel=1,
#                                       colsample_bynode=0.8, colsample_bytree=1,
#                                       eval_metrics='rmse', gamma=0, gpu_id=0,
#                                       learning_rate=1, max_delta_step=0,
#                                       max_depth=3, min_child_weight=1,
#                                       missing=None, n_estimators=100, n_jobs=14,
#                                       nthread=None, objective='reg:linear',
#                                       random_state=0, reg_alpha=0, reg_lambda=1,
#                                       scale_pos_weight=1, seed=None,
#                                       silent=None, subsample=0.8, verbosity=1),
#              iid='warn', n_jobs=None,
#              param_grid={'feature_selector': ['cyclic', 'greedy', 'thrifty'],
#                          'max_depth': [3, 5, 7],
#                          'objective': ['reg:squarederror'],
#                          'top_k': [1, 2, 3, 4]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=3)

# %%
pd.DataFrame(xgb_rf_reg_gscv.cv_results_)[['mean_test_score']]
# Out:
#     mean_test_score
# 0          0.634521
# 1          0.634521
# 2          0.634521
# 3          0.634521
# 4          0.678107
# 5          0.678107
# 6          0.678107
# 7          0.678107
# 8          0.683689
# 9          0.683689
# 10         0.683689
# 11         0.683689
# 12         0.634521
# 13         0.634521
# 14         0.634521
# 15         0.634521
# 16         0.678107
# 17         0.678107
# 18         0.678107
# 19         0.678107
# 20         0.683689
# 21         0.683689
# 22         0.683689
# 23         0.683689
# 24         0.634521
# 25         0.634521
# 26         0.634521
# 27         0.634521
# 28         0.678107
# 29         0.678107
# 30         0.678107
# 31         0.678107
# 32         0.683689
# 33         0.683689
# 34         0.683689
# 35         0.683689
